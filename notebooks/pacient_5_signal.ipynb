# %% [markdown]
# <font size = 6>**Patiant 5**</font>

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io
from pyedflib import highlevel
from scipy.fft import rfft

# %% [markdown]
# # look at pat 5

# %%
target = pd.read_csv("data_patient_5-lee.csv")

# %%
start_inx_h = 1500*256
start_inx_h
# Out:
# 384000

# %%
start_inx_s = 1679*256
start_inx_s
# Out:
# 429824

# %%
len_sec_h = (start_inx_s-start_inx_h)/256

# %%
target.iloc[:,-1][256*270]
# Out:
# 1

# %%
signals, signal_headers, header = highlevel.read_edf("../raw_data/eeg5.edf")

# %%
signals.shape
# Out:
# (21, 983296)

# %%
index_max_elec = np.std(signals,axis = 1)[:19].argmax()
index_max_elec
# Out:
# 16

# %%
elec_17 = signals[index_max_elec]
elec_17
# Out:
# array([1.52622771e+01, 3.09788176e+01, 3.02158787e+01, ...,
#        3.50000000e-03, 3.50000000e-03, 3.50000000e-03])

# %%
x = np.linspace(0,elec_17.shape[0])

# %%
plt.plot(elec_17[256*150:256*1900])

# %%
(256*1900-256*270)/256
# Out:
# 1630.0
