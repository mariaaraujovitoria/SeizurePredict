# %% [markdown]
# Goal: apply a DL model on different dataset
# - Preprocess with MinMaxScaler
# - Preprocess with CustomerTransformer

# %% [markdown]
# # Imports, variables, functions

# %%
import scipy.io
from pyedflib import highlevel
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import groupby
import csv
import pickle
from scipy.signal import butter, sosfilt, sosfiltfilt, sosfreqz
from scipy.signal import freqz, iirnotch, filtfilt
from sklearn.preprocessing import MinMaxScaler
from sklearn.base import TransformerMixin, BaseEstimator
import random
from sklearn.model_selection import cross_validate
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from scipy.fftpack import rfft
from sklearn.metrics import accuracy_score
import tensorflow as ts
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from plot_keras_history import plot_history
# Out:
# 2022-12-02 11:14:00.678528: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-02 11:14:01.161939: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-02 11:14:01.238235: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-02 11:14:01.238258: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-02 11:14:01.419267: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-02 11:14:02.491361: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-02 11:14:02.492357: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-02 11:14:02.492367: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
sample_rate = sampling_rate = 256
sec = 10
len_window = sample_rate*sec
overlap = 5

# Load annotation file
annt = scipy.io.loadmat('../raw_data/annotations_2017.mat')

# %%
## -- PREPROCESSING FUNCTIONS --

# Highpass filter
def highpass_filter(signals, sampling_rate, hp_frequency = 0.1):
    sos = butter(N = 3, Wn = hp_frequency, btype="highpass",fs=sampling_rate, output="sos")
    filter_hp = sosfiltfilt(sos, signals)
    return filter_hp

# Powerline filter
def notch_filter(signals, sampling_rate, notch_frequency = 50, quality_factor = 30):
    w0 = notch_frequency/(sampling_rate/2)
    b_notch, a_notch = iirnotch(w0, quality_factor)
    filter_notch = filtfilt(b_notch, a_notch, signals, axis = -1)
    return filter_notch

# Create our own scaler
class CustomTranformer(TransformerMixin, BaseEstimator): 
    # BaseEstimator generates the get_params() and set_params() methods that all Pipelines require
    # TransformerMixin creates the fit_transform() method from fit() and transform()
    
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        self.means = X.mean()
        return self
    
    def transform(self, X, y=None):
        norm_features = X - self.means
        return norm_features

# Combination of all filters and Scaler
def filter_signals(signals, sampling_rate, scaler, hp_frequency = 0.1, notch_frequency = 50, quality_factor = 30):
    filter_hp = highpass_filter(signals, sampling_rate)
    filter_notch = notch_filter(signals, sampling_rate, notch_frequency, quality_factor)
    final_signal = scaler.fit_transform(filter_notch)
    return final_signal

# %%
## -- LABEL FUNCTIONS --

# Format the EEG 
def eeg_formated(signals, names_ele):
    data_signals = signals.T # transpose the signals from datapoints
    data_signals = pd.DataFrame(data_signals) # create a pandas dataframe
    
    data_signals.columns = names_ele # rename columns
    
    return data_signals

# Format the annotations
def diagnosis(n):
    patient_A=annt["annotat_new"][0][n-1][0]
    patient_B=annt["annotat_new"][0][n-1][1]
    patient_C=annt["annotat_new"][0][n-1][2]
    
    #converting seconds to datapoints

    patient_A=patient_A.tolist()
    patient_B=patient_B.tolist()
    patient_C=patient_C.tolist()
    
    patient_A_dtp=[]
    patient_B_dtp=[]
    patient_C_dtp=[]  
    for elem in patient_A:
        for i in range(sampling_rate):
            patient_A_dtp.append(elem) 
    for elem in patient_B:
        for i in range(sampling_rate):
            patient_B_dtp.append(elem)
        
    for elem in patient_C:
        for i in range(sampling_rate):
            patient_C_dtp.append(elem)
            
    target_=pd.DataFrame({"Diagnosis A":patient_A_dtp,"Diagnosis B":patient_B_dtp,"Diagnosis C":patient_C_dtp})
    
    return target_  

# Add a time column with the seconds
def add_time(df):
    list_time=[]
    for i in range(len(df)):
        list_time.append(i//sampling_rate)
    df["time"]=list_time
    return df

# Create target variables when seizures lasts at least 10
def is_seizure(df):
    
    threshold = sampling_rate*10
    
    df['is_seizure_A'] = df["Diagnosis A"].groupby((df["Diagnosis A"] != df["Diagnosis A"].shift()).cumsum()).transform('size') * df["Diagnosis A"]
    df['is_seizure_A'] = (df['is_seizure_A'] > threshold).astype(int)
    
    df['is_seizure_B'] = df["Diagnosis B"].groupby((df["Diagnosis B"] != df["Diagnosis B"].shift()).cumsum()).transform('size') * df["Diagnosis B"]
    df['is_seizure_B'] = (df['is_seizure_B'] > threshold).astype(int)
    
    df['is_seizure_C'] = df["Diagnosis C"].groupby((df["Diagnosis C"] != df["Diagnosis C"].shift()).cumsum()).transform('size') * df["Diagnosis C"]
    df['is_seizure_C'] = (df['is_seizure_C'] > threshold).astype(int)
    
    return df 

# Create final target
def create_target(df):
    df['is_seizure_target'] = np.where(df['is_seizure_A'] + df['is_seizure_B'] + df['is_seizure_C'] >= 2, 1, 0)
    return df

# Remove useless
def remove_useless_columns(df):
    df.drop(columns=['Diagnosis A', 'Diagnosis B', 'Diagnosis C', 'is_seizure_A', 'is_seizure_B', 'is_seizure_C', 'ECG EKG', 'Resp Effort', 'time'], inplace=True)
    return df

# Final function to label
def label_data(path_raw_data, signals_preprocessed, n):
    
    signals, signal_headers, header = highlevel.read_edf(path_raw_data)
    
    names_ele = [signal_headers[iele]['label'] for iele in range(signals.shape[0])] # extract electrode names
    
    eeg_patient = eeg_formated(signals_preprocessed, names_ele) # format the ECG
    eeg_patient.rename(columns={'ECG EKG-REF':'ECG EKG', 'Resp Effort-REF':'Resp Effort'}, inplace=True)
    diagnosis_patient = diagnosis(n) # format the diagnosis
    
    data_patient = pd.merge(left=eeg_patient, right=diagnosis_patient, how='left', left_index=True, right_index=True) # merge ecg and diagnosis
    
    add_time(data_patient)
    is_seizure(data_patient)
    create_target(data_patient)
    remove_useless_columns(data_patient)
    
    return data_patient

# %%
## -- MODEL FUNCTIONS --

def flatten_window(window_df):
    if len(np.unique(window_df.iloc[:,-1])) == 1:
        target = window_df.iloc[0,-1]
    else:
        target = 1
    t_df = window_df.drop(columns = "is_seizure_target").transpose()
    flatten = pd.DataFrame(np.array(t_df).reshape(1,t_df.shape[0]*t_df.shape[1]))
    flatten["Target"] = target
    return flatten

def create_data_input(df):
    data = np.array([flatten_window(df.iloc[i:i+len_window+1]) for i in range(0,len(df)-len_window, overlap*sample_rate)])
    r=data.shape[0]
    c=data.shape[2]
    
    data = pd.DataFrame(data.reshape(r,c))
    X = data.iloc[:,:-1]
    y = data.iloc[:,-1]
    return X, y

def oversampling(X, y): 
    sm = SMOTE(sampling_strategy='minority', random_state=7)
    X, y = sm.fit_resample(X, y)
    return X, y

# %% [markdown]
# # Pipeline

# %%
def model_pipeline(path_raw_data, scaler, patient_number, Fournier=False):
    
    # Load raw data
    signals, signal_headers, header = highlevel.read_edf(path_raw_data)
    
    # Preprocess data 
    signals_preprocessed = filter_signals(signals, sampling_rate, scaler, hp_frequency = 0.1, notch_frequency = 50, quality_factor = 30)
    
    if Fournier == True:
        signals_preprocessed = pd.DataFrame(np.array([abs(rfft(signals_preprocessed[i])) for i in range(len(signals_preprocessed))]))
        
    # Label data
    df = label_data(path_raw_data, signals_preprocessed, patient_number)

    # Create data input
    X, y =  create_data_input(df)
    
    # Train/Test split
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
    
    # Balancing
    X_train, y_train = oversampling(X_train, y_train)
    
    # Implement model
    model = Sequential()
    model.add(layers.Dense(20, activation='relu', input_dim=X_train.shape[1]))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy', 
        metrics=[ts.keras.metrics.Recall(),"accuracy"])
    history=model.fit(X_train,y_train, batch_size=32, epochs=40)
    # Evaluation
    results_DL =model.evaluate(X_test, y_test)
    loss=results_DL[0]
    recall = results_DL[1]
    accuracy = results_DL[2]
    
    return loss, recall, accuracy

# %% [markdown]
# # Test DL model on different datasets

# %% [markdown]
# ## EEGs to test

# %%
## -- DO NOT RUN THIS CELL --

#patients_numbers = list(range(1, 80))

#patient_with_issue = [4, 29, 50] # Can't import ECG4, ECG29 and ECG50
#patient_without_seizure = [3, 6, 10, 12, 18, 24, 26, 27, 28, 30, 32, 35, 37, 42, 43, 45, 46, 48, 49, 53, 55, 56, 57, 58, 59, 60, 61, 64, 65, 70, 72, 74]

#for i in patient_with_issue:
 #   patients_numbers.remove(i)

#for i in patient_without_seizure:
 #   patients_numbers.remove(i)

# %% [markdown]
# ## Test on Preprocess data with MinMaxScaler

# %%
# Test for 5 patients
loss_1,recall_1, accuracy_1 = model_pipeline("../raw_data/eeg1.edf",  MinMaxScaler(), 1)
loss_5,recall_5, accuracy_5 = model_pipeline("../raw_data/eeg5.edf",  MinMaxScaler(), 5)
loss_25,recall_25, accuracy_25 = model_pipeline("../raw_data/eeg25.edf",  MinMaxScaler(), 25)
#recall_44, f1_score_44 = model_pipeline("../raw_data/eeg44.edf",  MinMaxScaler(), 44)
#recall_71, f1_score_71 = model_pipeline("../raw_data/eeg71.edf",  MinMaxScaler(), 71)
# Out:
# 2022-12-02 11:15:52.334594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:03:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-12-02 11:15:52.350211: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.350895: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.351860: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.352014: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.352951: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.354046: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.354329: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.354467: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-02 11:15:52.354522: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-02 11:15:52.408376: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/40
# 52/52 [==============================] - 3s 13ms/step - loss: 1.7896 - recall: 0.5749 - accuracy: 0.5469
# Epoch 2/40
# 52/52 [==============================] - 1s 10ms/step - loss: 1.0059 - recall: 0.6407 - accuracy: 0.6516
# Epoch 3/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4968 - recall: 0.8076 - accuracy: 0.7783
# Epoch 4/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5206 - recall: 0.7868 - accuracy: 0.7643
# Epoch 5/40
# 52/52 [==============================] - 1s 11ms/step - loss: 0.6512 - recall: 0.7844 - accuracy: 0.7808
# Epoch 6/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.6360 - recall: 0.7674 - accuracy: 0.7570
# Epoch 7/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5089 - recall: 0.8149 - accuracy: 0.8021
# Epoch 8/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3223 - recall: 0.8879 - accuracy: 0.8928
# Epoch 9/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2721 - recall: 0.9269 - accuracy: 0.9111
# Epoch 10/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2102 - recall: 0.9610 - accuracy: 0.9549
# Epoch 11/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2857 - recall: 0.9001 - accuracy: 0.9013
# Epoch 12/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1792 - recall: 0.9744 - accuracy: 0.9683
# Epoch 13/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2722 - recall: 0.9086 - accuracy: 0.8965
# Epoch 14/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1517 - recall: 0.9720 - accuracy: 0.9714
# Epoch 15/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1190 - recall: 0.9890 - accuracy: 0.9878
# Epoch 16/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1495 - recall: 0.9744 - accuracy: 0.9677
# Epoch 17/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1221 - recall: 0.9890 - accuracy: 0.9823
# Epoch 18/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0940 - recall: 0.9976 - accuracy: 0.9963
# Epoch 19/40
# 52/52 [==============================] - 0s 8ms/step - loss: 0.1015 - recall: 0.9927 - accuracy: 0.9915
# Epoch 20/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0900 - recall: 0.9976 - accuracy: 0.9951
# Epoch 21/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0996 - recall: 0.9878 - accuracy: 0.9896
# Epoch 22/40
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0746 - recall: 0.9988 - accuracy: 0.9982
# Epoch 23/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0662 - recall: 1.0000 - accuracy: 1.0000
# Epoch 24/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1976 - recall: 0.9391 - accuracy: 0.9361
# Epoch 25/40
# 52/52 [==============================] - 0s 9ms/step - loss: 0.6437 - recall: 0.7868 - accuracy: 0.7948
# Epoch 26/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.3299 - recall: 0.8879 - accuracy: 0.8879
# Epoch 27/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1244 - recall: 0.9708 - accuracy: 0.9665
# Epoch 28/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0897 - recall: 0.9866 - accuracy: 0.9829
# Epoch 29/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0566 - recall: 0.9988 - accuracy: 0.9976
# Epoch 30/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0502 - recall: 0.9988 - accuracy: 0.9994
# Epoch 31/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0445 - recall: 1.0000 - accuracy: 1.0000
# Epoch 32/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0422 - recall: 1.0000 - accuracy: 1.0000
# Epoch 33/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0421 - recall: 1.0000 - accuracy: 1.0000
# Epoch 34/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0406 - recall: 1.0000 - accuracy: 1.0000
# Epoch 35/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0383 - recall: 1.0000 - accuracy: 1.0000
# Epoch 36/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0374 - recall: 1.0000 - accuracy: 1.0000
# Epoch 37/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0366 - recall: 1.0000 - accuracy: 1.0000
# Epoch 38/40
# 52/52 [==============================] - 1s 13ms/step - loss: 0.0344 - recall: 1.0000 - accuracy: 1.0000
# Epoch 39/40
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0328 - recall: 1.0000 - accuracy: 1.0000
# Epoch 40/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0322 - recall: 1.0000 - accuracy: 1.0000
# 9/9 [==============================] - 0s 5ms/step - loss: 1.3373 - recall: 0.2667 - accuracy: 0.6536
# Epoch 1/40
# 33/33 [==============================] - 1s 9ms/step - loss: 1.5925 - recall_1: 0.5352 - accuracy: 0.5467
# Epoch 2/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5497 - recall_1: 0.7181 - accuracy: 0.7095
# Epoch 3/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.5178 - recall_1: 0.6743 - accuracy: 0.7038
# Epoch 4/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.3378 - recall_1: 0.8724 - accuracy: 0.8705
# Epoch 5/40
# 33/33 [==============================] - 0s 11ms/step - loss: 0.2906 - recall_1: 0.8724 - accuracy: 0.8943
# Epoch 6/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2835 - recall_1: 0.8819 - accuracy: 0.8857
# Epoch 7/40
# 33/33 [==============================] - 0s 11ms/step - loss: 0.1782 - recall_1: 0.9314 - accuracy: 0.9400
# Epoch 8/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1141 - recall_1: 0.9771 - accuracy: 0.9857
# Epoch 9/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1247 - recall_1: 0.9790 - accuracy: 0.9810
# Epoch 10/40
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1213 - recall_1: 0.9619 - accuracy: 0.9743
# Epoch 11/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0786 - recall_1: 0.9886 - accuracy: 0.9933
# Epoch 12/40
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0593 - recall_1: 0.9943 - accuracy: 0.9962
# Epoch 13/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0518 - recall_1: 0.9981 - accuracy: 0.9981
# Epoch 14/40
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0446 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 15/40
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0389 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 16/40
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0346 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 17/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0308 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 18/40
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0276 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 19/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0238 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 20/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0214 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 21/40
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0198 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 22/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0182 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 23/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0180 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 24/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0151 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 25/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0137 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 26/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0125 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 27/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0113 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 28/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0105 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 29/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0116 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 30/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0087 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 31/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0081 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 32/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0079 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 33/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0072 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 34/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0070 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 35/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0063 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 36/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0060 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 37/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0058 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 38/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0054 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 39/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0051 - recall_1: 1.0000 - accuracy: 1.0000
# Epoch 40/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0047 - recall_1: 1.0000 - accuracy: 1.0000
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1055 - recall_1: 0.9200 - accuracy: 0.7727
# Epoch 1/40
# 65/65 [==============================] - 3s 16ms/step - loss: 0.7562 - recall_2: 0.7563 - accuracy: 0.6985
# Epoch 2/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0912 - recall_2: 0.9923 - accuracy: 0.9841
# Epoch 3/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0381 - recall_2: 0.9981 - accuracy: 0.9961
# Epoch 4/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0192 - recall_2: 1.0000 - accuracy: 0.9995
# Epoch 5/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0161 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 6/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0125 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 7/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0096 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 8/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0090 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 9/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0079 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 10/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0073 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 11/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0067 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 12/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0062 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 13/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0059 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 14/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0057 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 15/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0055 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 16/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0053 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 17/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0050 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 18/40
# 65/65 [==============================] - 1s 15ms/step - loss: 0.0049 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 19/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0048 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 20/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0047 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 21/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0046 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 22/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0044 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 23/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0044 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 24/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0043 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 25/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0042 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 26/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0041 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 27/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0041 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 28/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0040 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 29/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0040 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 30/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0039 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 31/40
# 65/65 [==============================] - 1s 14ms/step - loss: 0.0038 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 32/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0037 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 33/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0037 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 34/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0036 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 35/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0035 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 36/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0035 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 37/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0034 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 38/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0034 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 39/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0033 - recall_2: 1.0000 - accuracy: 1.0000
# Epoch 40/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0032 - recall_2: 1.0000 - accuracy: 1.0000
# 9/9 [==============================] - 1s 6ms/step - loss: 0.6759 - recall_2: 0.0000e+00 - accuracy: 0.9216

# %%
print(f"patient 1:{loss_1, recall_1, accuracy_1}")
print(f"patient 5:{loss_5, recall_5, accuracy_5}")
print(f"patient 25:{loss_25, recall_25, accuracy_25}")
# Out:
# patient 1:(1.3372727632522583, 0.2666666805744171, 0.6535714268684387)
# patient 5:(1.1054766178131104, 0.9200000166893005, 0.7727272510528564)
# patient 25:(0.6758911609649658, 0.0, 0.9216417670249939)

# %%
## -- DO NOT RUN THIS CELL --

#recall_minmax = []
#f1_score_minmax = []

#for i in patients_numbers:
 #   recall_i, f1_score_i = model_pipeline(f"../raw_data/eeg{i}.edf",  MinMaxScaler(), i)
  #  recall_minmax.append(recall_i)
   # f1_score_minmax.append(f1_score_i)

# %% [markdown]
# ## Test on Preprocess data with CustomerTransformer

# %%
# Test for 5 patients
loss_1_custom,recall_1_custom, accuracy_score_1_custom = model_pipeline("../raw_data/eeg1.edf",  CustomTranformer(), 1)
loss_5_custom,recall_5_custom, accuracy_score_5_custom = model_pipeline("../raw_data/eeg5.edf",  CustomTranformer(), 5)
loss_25_custom,recall_25_custom, accuracy_score_25_custom = model_pipeline("../raw_data/eeg25.edf",  CustomTranformer(), 25)
#recall_44_custom, f1_score_44_custom = model_pipeline("../raw_data/eeg44.edf",  CustomTranformer(), 44)
40
# 33/33 [==============================] - 0s 9ms/step - loss: 0.4353 - recall_4: 0.9865 - accuracy: 0.9730
# Epoch 29/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2121 - recall_4: 0.9904 - accuracy: 0.9817
# Epoch 30/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0260 - recall_4: 0.9981 - accuracy: 0.9846
# Epoch 31/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0195 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 32/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0192 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 33/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0189 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 34/40
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0187 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 35/40
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0185 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 36/40
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0183 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 37/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0181 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 38/40
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0180 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 39/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0179 - recall_4: 1.0000 - accuracy: 0.9855
# Epoch 40/40
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0178 - recall_4: 1.0000 - accuracy: 0.9855
# 5/5 [==============================] - 0s 9ms/step - loss: 183.2773 - recall_4: 0.7939 - accuracy: 0.6948
# Epoch 1/40
# 65/65 [==============================] - 3s 16ms/step - loss: 30.5148 - recall_5: 0.8243 - accuracy: 0.8160
# Epoch 2/40
# 65/65 [==============================] - 1s 14ms/step - loss: 3.8597 - recall_5: 0.9350 - accuracy: 0.9354
# Epoch 3/40
# 65/65 [==============================] - 1s 13ms/step - loss: 2.7293 - recall_5: 0.9553 - accuracy: 0.9534
# Epoch 4/40
# 65/65 [==============================] - 1s 10ms/step - loss: 1.3848 - recall_5: 0.9553 - accuracy: 0.9641
# Epoch 5/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.5607 - recall_5: 0.9738 - accuracy: 0.9772
# Epoch 6/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1247 - recall_5: 0.9709 - accuracy: 0.9811
# Epoch 7/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0893 - recall_5: 0.9748 - accuracy: 0.9850
# Epoch 8/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1361 - recall_5: 0.9757 - accuracy: 0.9864
# Epoch 9/40
# 65/65 [==============================] - 1s 9ms/step - loss: 1.1285 - recall_5: 0.9534 - accuracy: 0.9650
# Epoch 10/40
# 65/65 [==============================] - 1s 12ms/step - loss: 13.4297 - recall_5: 0.9117 - accuracy: 0.9316
# Epoch 11/40
# 65/65 [==============================] - 1s 12ms/step - loss: 3.8960 - recall_5: 0.9165 - accuracy: 0.9311
# Epoch 12/40
# 65/65 [==============================] - 1s 12ms/step - loss: 1.0291 - recall_5: 0.9524 - accuracy: 0.9617
# Epoch 13/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2441 - recall_5: 0.9971 - accuracy: 0.9820
# Epoch 14/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1135 - recall_5: 0.9981 - accuracy: 0.9845
# Epoch 15/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0865 - recall_5: 1.0000 - accuracy: 0.9859
# Epoch 16/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0761 - recall_5: 1.0000 - accuracy: 0.9859
# Epoch 17/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0692 - recall_5: 1.0000 - accuracy: 0.9864
# Epoch 18/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0636 - recall_5: 1.0000 - accuracy: 0.9864
# Epoch 19/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0582 - recall_5: 1.0000 - accuracy: 0.9864
# Epoch 20/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0528 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 21/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0473 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 22/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0418 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 23/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0368 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 24/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0328 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 25/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0326 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 26/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0323 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 27/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0322 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 28/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0320 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 29/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0318 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 30/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0317 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 31/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0315 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 32/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0314 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 33/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0312 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 34/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0311 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 35/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.0310 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 36/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0309 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 37/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0308 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 38/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0307 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 39/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0306 - recall_5: 1.0000 - accuracy: 0.9869
# Epoch 40/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0305 - recall_5: 1.0000 - accuracy: 0.9869
# 9/9 [==============================] - 1s 36ms/step - loss: 60.4990 - recall_5: 0.0000e+00 - accuracy: 0.8955

# %%
print(f"patient 1:{loss_1_custom, recall_1_custom, accuracy_score_1_custom}")
print(f"patient 5:{loss_5_custom, recall_5_custom, accuracy_score_5_custom}")
print(f"patient 25:{loss_25_custom, recall_25_custom, accuracy_score_25_custom}")
# Out:
# patient 1:(29.168012619018555, 0.3253012001514435, 0.6607142686843872)
# patient 5:(183.2772979736328, 0.7938931584358215, 0.6948052048683167)
# patient 25:(60.49898147583008, 0.0, 0.89552241563797)

# %%
## -- DO NOT RUN THIS CELL --

#recall_custom = []
#f1_score_custom = []

#for i in patients_numbers:
 #   recall_i, f1_score_i = model_pipeline(f"../raw_data/eeg{i}.edf",  CustomTransformer(), i)
  #  recall_custom.append(recall_i)
   # f1_score_custom.append(f1_score_i)

# %% [markdown]
# ## Test on Preprocess data with CustomTransformer and Fourrier filter

# %%
loss_1_fourrier,recall_1_fourrier, accuracy_score_1_fourrier = model_pipeline("../raw_data/eeg1.edf",  CustomTranformer(), 1, Fournier=True)
loss_5_fourrier,recall_5_fourrier, accuracy_score_5_fourrier = model_pipeline("../raw_data/eeg5.edf",  CustomTranformer(), 5, Fournier=True)
loss_25_fourrier,recall_25_fourrier, accuracy_score_25_fourrier = model_pipeline("../raw_data/eeg25.edf",  CustomTranformer(), 25, Fournier=True)
#recall_44_fournier, f1_score_44_fournier = model_pipeline("../raw_data/eeg44.edf",  CustomTranformer(), 44, Fournier=True)
#recall_71_fournier, f1_score_71_fournier = model_pipeline("../raw_data/eeg71.edf",  CustomTranformer(), 71, Fournier=True)
# Out:
# Epoch 1/40
# 52/52 [==============================] - 2s 11ms/step - loss: 3700.2881 - recall_9: 0.4603 - accuracy: 0.5487
# Epoch 2/40
# 52/52 [==============================] - 1s 11ms/step - loss: 466.5170 - recall_9: 0.5901 - accuracy: 0.6148
# Epoch 3/40
# 52/52 [==============================] - 1s 11ms/step - loss: 114.8029 - recall_9: 0.7308 - accuracy: 0.7007
# Epoch 4/40
# 52/52 [==============================] - 0s 9ms/step - loss: 30.3343 - recall_9: 0.8077 - accuracy: 0.8071
# Epoch 5/40
# 52/52 [==============================] - 0s 9ms/step - loss: 16.1901 - recall_9: 0.8474 - accuracy: 0.8510
# Epoch 6/40
# 52/52 [==============================] - 1s 10ms/step - loss: 12.3588 - recall_9: 0.8702 - accuracy: 0.8654
# Epoch 7/40
# 52/52 [==============================] - 0s 9ms/step - loss: 7.1830 - recall_9: 0.9026 - accuracy: 0.9032
# Epoch 8/40
# 52/52 [==============================] - 1s 10ms/step - loss: 2.1371 - recall_9: 0.9579 - accuracy: 0.9555
# Epoch 9/40
# 52/52 [==============================] - 1s 10ms/step - loss: 1.5561 - recall_9: 0.9579 - accuracy: 0.9549
# Epoch 10/40
# 52/52 [==============================] - 1s 10ms/step - loss: 0.3293 - recall_9: 0.9844 - accuracy: 0.9850
# Epoch 11/40
# 52/52 [==============================] - 1s 13ms/step - loss: 0.1872 - recall_9: 0.9952 - accuracy: 0.9940
# Epoch 12/40
# 52/52 [==============================] - 1s 12ms/step - loss: 0.5078 - recall_9: 0.9796 - accuracy: 0.9778
# Epoch 13/40
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2123 - recall_9: 0.9880 - accuracy: 0.9880
# Epoch 14/40
# 52/52 [==============================] - 1s 11ms/step - loss: 0.
40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6943 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 7/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6934 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 8/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6925 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 9/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6917 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 10/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6910 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 11/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6904 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 12/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.6897 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 13/40
# 65/65 [==============================] - 1s 12ms/step - loss: 0.6892 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 14/40
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6887 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 15/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6884 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 16/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6880 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 17/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6878 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 18/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6875 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 19/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6874 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 20/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6872 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 21/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6871 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 22/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6870 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 23/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6869 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 24/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6869 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 25/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6868 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 26/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6868 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 27/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6868 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 28/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6868 - recall_11: 1.0000 - accuracy: 0.5010
# Epoch 29/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6868 - recall_11: 0.3518 - accuracy: 0.4888
# Epoch 30/40
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6868 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 31/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6868 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 32/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 33/40
# 65/65 [==============================] - 1s 9ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 34/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 35/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 36/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 37/40
# 65/65 [==============================] - 1s 10ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 38/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6868 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 39/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# Epoch 40/40
# 65/65 [==============================] - 1s 11ms/step - loss: 0.6867 - recall_11: 0.0165 - accuracy: 0.5083
# 9/9 [==============================] - 1s 61ms/step - loss: 0.6894 - recall_11: 0.0000e+00 - accuracy: 0.9552

# %%
print(f"patient 1:{loss_1_fourrier, recall_1_fourrier, accuracy_score_1_fourrier}")
print(f"patient 5:{loss_5_fourrier, recall_5_fourrier, accuracy_score_5_fourrier}")
print(f"patient 25:{loss_25_fourrier, recall_25_fourrier, accuracy_score_25_fourrier}")
# Out:
# patient 1:(886.3180541992188, 0.3380281627178192, 0.699999988079071)
# patient 5:(0.6782591938972473, 0.7259259223937988, 0.701298713684082)
# patient 25:(0.6894007921218872, 0.0, 0.9552238583564758)

# %%
## -- DO NOT RUN THIS CELL --

#recall_fournier = []
#f1_score_fournier = []

#for i in patients_numbers:
 #   recall_i, f1_score_i = model_pipeline(f"../raw_data/eeg{i}.edf",  CustomTransformer(), i, Fournier=True)
  #  recall_fournier.append(recall_i)
   # f1_score_fournier.append(f1_score_i)

# %% [markdown]
# # Results

# %%
# Test for 5 patients
patients_numbers = [1, 5, 25, 44, 71]
recall_minmax = [recall_1, recall_5, recall_25, recall_44, recall_71]
recall_custom = [recall_1_custom, recall_5_custom, recall_25_custom, recall_44_custom, recall_71_custom]
recall_fournier = [recall_1_fournier, recall_5_fournier, recall_25_fournier, recall_44_fournier, recall_71_fournier]
f1_score_minmax = [f1_score_1, f1_score_5, f1_score_25, f1_score_44, f1_score_71]
f1_score_custom = [f1_score_1_custom, f1_score_5_custom, f1_score_25_custom, f1_score_44_custom, f1_score_71_custom]
f1_score_fournier = [f1_score_1_fournier, f1_score_5_fournier, f1_score_25_fournier, f1_score_44_fournier, f1_score_71_fournier]

results  = pd.DataFrame(recall_minmax, patients_numbers)
results.rename(columns={0:'recall_minmax'}, inplace=True)
results['recall_custom'] = recall_custom
results['recall_fournier'] = recall_fournier
results['f1_score_minmax'] = f1_score_minmax
results['f1_score_custom'] = f1_score_custom
results['f1_score_fournier'] = f1_score_fournier
results
